# %%
from tensorflow.keras.datasets import cifar10

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
x_train_small = x_train[:100]
y_train_small = y_train[:100]

x_test_small = x_test[:20]
y_test_small = y_test[:20]

# %%
x_train_small=x_train_small/255.0
x_test_small=x_test_small/255.

# %%
import tensorflow as tf
from tensorflow.keras import layers,models

# %%
model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile( optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    x_train_small,
    y_train_small,
    epochs=10,
    validation_data=(x_test_small, y_test_small)
)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.1200 - loss: 2.2986 - val_accuracy: 0.1000 - val_loss: 2.2946
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1800 - loss: 2.2615 - val_accuracy: 0.1500 - val_loss: 2.3044
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2100 - loss: 2.2372 - val_accuracy: 0.1500 - val_loss: 2.3151
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2400 - loss: 2.2078 - val_accuracy: 0.1500 - val_loss: 2.3361
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2500 - loss: 2.1740 - val_accuracy: 0.1000 - val_loss: 2.3693
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2200 - loss: 2.1475 - val_accuracy: 0.1000 - val_loss: 2.4268
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2100 - loss: 2.1283 - val_accuracy: 0.1000 - val_loss: 2.5047
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.1900 - loss: 2.1019 - val_accuracy: 0.1000 - val_loss: 2.5437
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1900 - loss: 2.0669 - val_accuracy: 0.0500 - val_loss: 2.5552
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2300 - loss: 2.0314 - val_accuracy: 0.0500 - val_loss: 2.5701
