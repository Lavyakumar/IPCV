# %%
import cv2

# %%
img= cv2.imread('/content/img.jpeg',0)

# %%
contours, _= cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

# %%
for cnt in contours:
  print("Boundary points:",len(cnt))
# Out:
# Boundary points: 4
# Boundary points: 9446
