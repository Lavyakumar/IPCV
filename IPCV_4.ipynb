# %% [markdown]
# <a href="https://colab.research.google.com/github/Lavyakumar/IPCV/blob/main/IPCV_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 #read img
import numpy as np #maths
import matplotlib.pyplot as plt #plotting

# %%
from google.colab import files
import io
from PIL import Image

# %%
uploaded=files.upload

# %%
img =cv2.imread('/content/eagle_img.webp', 0 ) #grayscale0

# %%
f= np.fft.fft2(img) #(H freq abhi center mai h) fft algo mai ff2 fn for 2D img to conver img into frequency spectrum

# %%
fshift= np.fft.fftshift(f) # low mid mai aa gai

# %%
row, col= img.shape

# %%
crow, ccol= row//2,col//2

# %% [markdown]
# for the center
#
# ---

# %%
mask_lp=np.zeros((row,col),np.uint8)

# %% [markdown]
# img ke size ka matrix jiski sari value h 0
#
#
# ---
# center ki value ko 1 krdenge

# %%
mask_lp[crow-30:crow+30,ccol-30:ccol+30]=1

# %%
lp=np.fft.ifft2(np.fft.ifftshift(fshift*mask_lp))

# %% [markdown]
# low mid wali ko mask se multiplay kra then inverse then pixel mai

# %%
cv2.imwrite("lpf_eagle.png", np.abs(lp))
# Out:
# True

# %%
from google.colab import files

# %%
files.download("lpf_eagle.png")

# %%
mask_hp=1-mask_lp

# %%
mask_hp[crow-30:crow+30,ccol-30:ccol+30]=0

# %%
hp=np.fft.ifft2(np.fft.ifftshift(fshift*mask_hp))

# %%
cv2.imwrite("hpf_eagle.png", np.abs(hp))
# Out:
# True

# %%
files.download("hpf_eagle.png")
