# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

# %%
img = cv2.imread("/content/img.jpg",0)

# %%
_, binary = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
adaptive=cv2.adaptiveThreshold(img,255,
                               cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                               cv2.THRESH_BINARY,11,2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_678/297125965.py in <cell line: 0>()
# ----> 1 adaptive=cv2.adaptiveThreshold(img,255,
#       2                                cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
#       3                                cv2.THRESH_BINARY,11,2)
#
# error: OpenCV(4.13.0) /io/opencv/modules/imgproc/src/smooth.dispatch.cpp:618: error: (-215:Assertion failed) !_src.empty() in function 'GaussianBlur'

# %%
cv2.imwrite("binary.jpg",binary)
cv2.imwrite("adaptive.jpg",adaptive)
# Out:
# True

# %%
mean= np.mean(img)

# %%
variance=np.var(img)

# %%
edges= cv2.Canny(img,100,200)

# %%
cv2.imwrite("edges.jpg",edges)
# Out:
# True

# %%
gray= cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

# %%
gray= np.float32(img)

# %%
corners= cv2.cornerHarris(gray,2,3,0.04)

# %%
#save
cv2.imwrite("corners.jpg",corners)
# Out:
# True

# %%
img=cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

# %%
img[corners>0.01*corners.max()]=[0,0,255]

# %%
#save

# %%
#save
cv2.imwrite("corners2.jpg",img)
# Out:
# True
